# %% [markdown]
# DIMENSIONALITY REDUCTION USING INBUILT DATASET IRIS

# %%
#importing necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Visualize the reduced data
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k', s=100)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Iris Dataset')
plt.colorbar(label='Class')
plt.show()

# %% [markdown]
# STOCK PRICE PREDICTION USING TIME SERIES FORCASTING USING TESLA'S DATASET

# %%
#importing necessary librariesimport pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error





# Feature Engineering: Create lag features
df['Lag_1'] = df['Close'].shift(1)

# Drop rows with NaN values (due to lag features)
df.dropna(inplace=True)

# Train ARIMA model
train_size = int(len(df) * 0.8)
train, test = df.iloc[:train_size], df.iloc[train_size:]

# Fit ARIMA model
model = ARIMA(train['Close'], order=(5, 1, 0))  # Example: (p, d, q) = (5, 1, 0)
model_fit = model.fit()

# Forecast
forecast = model_fit.forecast(steps=len(test))

# Evaluate the model
mae = mean_absolute_error(test['Close'], forecast)
rmse = np.sqrt(mean_squared_error(test['Close'], forecast))
print(f'MAE: {mae}, RMSE: {rmse}')

# Visualize predictions vs actual
plt.figure(figsize=(10, 6))
plt.plot(test.index, test['Close'], label='Actual')
plt.plot(test.index, forecast, label='Predicted', color='red')
plt.title('ARIMA: Actual vs Predicted Close Prices')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 8
#       5 from sklearn.metrics import mean_absolute_error, mean_squared_error
#       7 # Load the dataset
# ----> 8 df = pd.read_csv('stock_prices.csv')
#      10 # Preprocessing
#      11 df['Date'] = pd.to_datetime(df['Date'])
#
# ...

# %%
# Load the dataset
df = pd.read_csv('tesla_stock_prices.csv')

# %%
# Preprocessing
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.fillna(method='ffill', inplace=True)  # Handle missing values

# %%
# EDA: Plot Close prices
plt.figure(figsize=(10, 6))
plt.plot(df['Close'])
plt.title('Historical Close Prices')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %%
# Feature Engineering: Create lag features
df['Lag_1'] = df['Close'].shift(1)

# %%
# Drop rows with NaN values (due to lag features)
df.dropna(inplace=True)

# %%
# Train ARIMA model
train_size = int(len(df) * 0.8)
train, test = df.iloc[:train_size], df.iloc[train_size:]

# %%
# Fit ARIMA model
model = ARIMA(train['Close'], order=(5, 1, 0))  # Example: (p, d, q) = (5, 1, 0)
model_fit = model.fit()

# %%
# Forecast
forecast = model_fit.forecast(steps=len(test))
